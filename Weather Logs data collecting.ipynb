# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time
import csv

# %%
with open('messurments_log.csv', 'w') as f:
    fnames = ['temp', 'wind', 'humidity', 'visibility', 'presure', 'time_now']
    writer = csv.DictWriter(f, fieldnames=fnames)
    writer.writeheader()
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        temp = soup.find('div', attrs={'class': 'temp'}).get_text()
        temp = float(temp.split('°')[0])
        wind = float(soup.find('span', attrs={'class': 'white'}).find('b').get_text().strip())
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                presure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")

        
        output = {'temp': temp, 'wind': wind, 'humidity': humidity, 'visibility': visibility, 'presure': presure, 'time_now': time_now}
        writer.writerow(output)

        
        print(f'scrapping done for {i+1} times at {time_now}')
        time.sleep(1)
# Out:
# scrapping done for 1 times at 19/08/2021 22:27:35
# scrapping done for 2 times at 19/08/2021 22:27:38
# scrapping done for 3 times at 19/08/2021 22:27:40
# scrapping done for 4 times at 19/08/2021 22:27:42
# scrapping done for 5 times at 19/08/2021 22:27:45
# scrapping done for 6 times at 19/08/2021 22:27:47
# scrapping done for 7 times at 19/08/2021 22:27:50
# scrapping done for 8 times at 19/08/2021 22:27:52
# scrapping done for 9 times at 19/08/2021 22:27:54
# scrapping done for 10 times at 19/08/2021 22:27:57

# %%
import pandas as pd

data = pd.read_csv('messurments_log.csv')
data
# Out:
#    temp  wind  humidity  visibility  presure             time_now
# 0  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:35
# 1  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:38
# 2  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:40
# 3  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:42
# 4  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:45
# 5  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:47
# 6  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:50
# 7  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:52
# 8  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:54
# 9  29.0  19.0      66.0     10000.0   1007.0  19/08/2021 22:27:57
